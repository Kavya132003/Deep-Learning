# %% [markdown]
# **22nd July 2026**

# %% [markdown]
# **Pre-requisites**
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Data pipelines
# 5. Machine Learning
# 6. Statistics and Probability
#
# **Libraries**:
# * Tensorflow and keras (google) or PyTorch (FaceBook)

# %% [markdown]
# **Module1**: Introduction to Deep Learning
# * What is deep learning?
# * Difference between ML and DL
# * Biological vs Artificial Neural Networks
# * Why deep learning works - representation of deep learning
# * Applications
#
# **Module2**: Neural Network Fundamentals
# * Perceptron and multi-layer perceptron
# * Activation functions(ReLU, Sigmoid, Tanh...)
# * Loss Functions(MSE,Binary Cross entropy, Categorical cross entropy)
# * Forward propagation
# * Backpropagation(gradient descent, batch, mini-batch)
# * Weight initialization
# * Optimizers(SGD,Momentum,Adam...)
#
# **Module3**: Training Deep Neural Networks
# * Overfitting vs underfitting
# * Regularization
#   1. L1 and L2
#   2. Dropout
#   3. Early stopping
# * Batch Normalization
# * Hyperparameter Tuning
#   1. Learning rate
#   2. Batch size
#   3. Epochs
#   4. Grid Search, Random search, Bayesian optimization
#
# **Module4**: Convolutional Neural Network (CNN)
# * What is convolution?
# * Filters, Feature Maps
# * Stride, Padding
# * Pooling Layers
# * Flatten vs Global Average Pooling
# * Architecture Fundamentals:
#   1. LeNet
#   2. AlexNet
#   3. VGG
#   4. ResNet(skip connections)
#
# **Module5**: Recurrent Neural Network(RNN)
# * Sequence data in deep learning
# * Basics of RNNs
# * Vanishing and Exploding Gradient Problem
# * LSTMs - gates and working
# * GRUs
# * Bidirectional RNNs
# * Encoder - Decoder architecture
#
# **Module6**: NLP(Natural Language Processing) - Deep Learning Based
# * Word embeddings(Word2Vec, Glove)
# * Embedding Layers
# * Attention Mechanism
# * Transformers (conceptual)
# * BERT architecture overview
# * Transfer Learning in NLP

# %% [markdown]
# **Self-Learning Modules**
# 1
